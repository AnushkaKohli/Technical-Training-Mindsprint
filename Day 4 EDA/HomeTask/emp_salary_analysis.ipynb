# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('EMP_DATA.csv')
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      100 non-null    int64
#  1   name        100 non-null    object
#  2   age         100 non-null    int64
#  3   email       100 non-null    object
#  4   department  100 non-null    object
#  5   salary      100 non-null    int64
#  6   experience  100 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 5.6+ KB
# None

# %%
df
# Out:
#     emp_id             name  age                               email  \
# 0        1   Daren Philipps   20              dphilipps0@godaddy.com
# 1        2      Aube Cabral   43                    acabral1@nyu.edu
# 2        3    Charin Labbet   40                 clabbet2@reddit.com
# 3        4    Lucilia Ivory   43                     livory3@163.com
# 4        5  Zechariah Ferry   53                 zferry4@squidoo.com
# ..     ...              ...  ...                                 ...
# 95      96  Enrika Woollons   44  ewoollons2n@networkadvertising.org
# 96      97   Rowe D'Ambrogi   57              rdambrogi2o@sphinn.com
# 97      98    Ashlin Kenrat   34             akenrat2p@aboutads.info
# 98      99    Fonsie Parlor   33               fparlor2q@godaddy.com
# 99     100     Randi Pucker   43                 rpucker2r@diigo.com
#
#                   department  salary  experience
# 0   Research and Development  680084          18
# 1                    Support  632217          12
# 2         Product Management  553851          20
# 3                   Services  142611          11
# 4                   Services  927624           1
# ..                       ...     ...         ...
# 95               Engineering  413296           4
# 96      Business Development  255583           5
# 97               Engineering   72268           4
# 98           Human Resources   49373           8
# 99                 Marketing   51941          12
#
# [100 rows x 7 columns]

# %%
# Average Salary in Each Department
average_salary_by_department = df.groupby('department')['salary'].mean()
print("Average Salary in Each Department:")
print(average_salary_by_department)
# Out:
# Average Salary in Each Department:
# department
# Accounting                  444282.846154
# Business Development        416133.800000
# Engineering                 382944.500000
# Human Resources             540192.571429
# Legal                       484593.625000
# Marketing                   473590.250000
# Product Management          561907.714286
# Research and Development    532069.666667
# Sales                       753696.625000
# Services                    456234.272727
# Support                     699889.000000
# Training                    495305.000000
# Name: salary, dtype: float64

# %%
# Highest and Lowest Salary in the Company
highest_salary = df['salary'].max()
lowest_salary = df['salary'].min()
print("Highest Salary in the Company:", highest_salary)
print("Lowest Salary in the Company:", lowest_salary)
# Out:
# Highest Salary in the Company: 996616
# Lowest Salary in the Company: 12152

# %%
# Employee with the Maximum Salary
employee_with_max_salary = df[df['salary'] == highest_salary]
print("Employee with the Maximum Salary:")
print(employee_with_max_salary)
# Out:
# Employee with the Maximum Salary:
#     emp_id           name  age                  email department  salary  \
# 23      24  Emlynne Keary   21  ekearyn@over-blog.com      Sales  996616
#
#     experience
# 23          17

# %%
# Count the Number of Employees in Each Department
employee_count_by_department = df['department'].value_counts()
print("Number of Employees in Each Department:")
print(employee_count_by_department)
# Out:
# Number of Employees in Each Department:
# department
# Accounting                  13
# Services                    11
# Business Development        10
# Sales                        8
# Engineering                  8
# Legal                        8
# Marketing                    8
# Support                      7
# Training                     7
# Product Management           7
# Human Resources              7
# Research and Development     6
# Name: count, dtype: int64

# %%
# Bar Chart Showing the Number of Employees in Each Department
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
employee_count_by_department.plot(kind='bar', title='Number of Employees in Each Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.show()

# %%
# Plot a Pie Chart Showing Salary Distribution by Department
total_salary_by_department = df.groupby('department')['salary'].sum()
plt.figure(figsize=(10, 6))
total_salary_by_department.plot(kind='pie', title='Salary Distribution by Department', autopct='%1.1f%%')
plt.show()

# %%
# Scatter Plot Showing Salary vs Experience
plt.figure(figsize=(10, 6))
plt.scatter(df['experience'], df['salary'])
plt.title('Salary vs Experience')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
# Employees Who Earn More Than the Average Salary
average_salary = df['salary'].mean()
employees_above_average_salary = df[df['salary'] > average_salary]
print("Employees Who Earn More Than the Average Salary:")
print(employees_above_average_salary)
# Out:
# Employees Who Earn More Than the Average Salary:
#     emp_id                 name  age                         email  \
# 0        1       Daren Philipps   20        dphilipps0@godaddy.com
# 1        2          Aube Cabral   43              acabral1@nyu.edu
# 2        3        Charin Labbet   40           clabbet2@reddit.com
# 4        5      Zechariah Ferry   53           zferry4@squidoo.com
# 7        8         Earvin Kraut   41           ekraut7@cornell.edu
# 13      14          Si Thowless   60         sthowlessd@seesaa.net
# 15      16       Cynthy Greenin   25     cgreeninf@statcounter.com
# 16      17           Nye MacKim   18            nmackimg@cam.ac.uk
# 17      18         Darius Hames   40         dhamesh@sitemeter.com
# 19      20       Hettie Iannini   22          hianninij@tumblr.com
# 20      21       Melany Drayson   52       mdraysonk@wikimedia.org
# 23      24        Emlynne Keary   21         ekearyn@over-blog.com
# 24      25         Korney Slane   33   kslaneo@cargocollective.com
# 25      26        Phedra Irving   35      pirvingp@bizjournals.com
# 26      27          Suzi Boyton   30        sboytonq@amazonaws.com
# 29      30         Mathew Exley   28         mexleyt@discovery.com
# 31      32     Heinrick Mahmood   30       hmahmoodv@google.com.br
# 32      33       Cammy Redemile   35         credemilew@netlog.com
# 33      34         Odie Asquith   35              oasquithx@nhs.uk
# 36      37       Annette Baline   54      abaline10@craigslist.org
# 38      39     Carlin Del Monte   34           cdel12@google.co.uk
# 42      43         Saudra Boldt   40       sboldt16@soundcloud.com
# 43      44          Flinn Algie   60          falgie17@godaddy.com
# 44      45         Leland Pecha   39            lpecha18@umich.edu
# 45      46     Randie McIlvenna   49   rmcilvenna19@altervista.org
# 46      47      Esteban McFeate   54           emcfeate1a@live.com
# 48      49          Elly Davitt   34     edavitt1c@marketwatch.com
# 49      50          Aurora Loft   42             aloft1d@exblog.jp
# 50      51        Iain Vanichev   57      ivanichev1e@virginia.edu
# 53      54       Doti Geistmann   19  dgeistmann1h@telegraph.co.uk
# 58      59          Anna Onions   38         aonions1m@archive.org
# 63      64     Laureen Shearsby   59             lshearsby1r@51.la
# 64      65       Husain Grastye   60           hgrastye1s@narod.ru
# 67      68       Niels Davidove   59        ndavidove1v@ebay.co.uk
# 69      70          Booth Hehir   56    bhehir1x@ezinearticles.com
# 70      71      Carlene Cropper   45      ccropper1y@wordpress.com
# 71      72        Kerk Chazette   40         kchazette1z@wired.com
# 74      75          Mead Dellar   37          mdellar22@toplist.cz
# 77      78         Rouvin Blann   56          rblann25@booking.com
# 80      81     Phillis Langeley   29         plangeley28@imgur.com
# 81      82        Dianna Winger   26             dwinger29@hud.gov
# 83      84  Clementine Anthoney   44     canthoney2b@amazonaws.com
# 85      86       Vitoria Coller   40             vcoller2d@irs.gov
# 86      87    Carolyne Castelin   45     ccastelin2e@goodreads.com
# 87      88         Renee Vivien   49             rvivien2f@nba.com
# 88      89   Konstantine Flello   23             kflello2g@nyu.edu
# 89      90          Baxie Copin   19      bcopin2h@theatlantic.com
# 90      91      Austine Jimenez   58         ajimenez2i@flickr.com
# 91      92      Fabiano Yeoland   25           fyeoland2j@ehow.com
# 93      94       Daryn Fancourt   26           dfancourt2l@ihg.com
#
#                   department  salary  experience
# 0   Research and Development  680084          18
# 1                    Support  632217          12
# 2         Product Management  553851          20
# 4                   Services  927624           1
# 7                      Sales  869548           6
# 13                 Marketing  908867           2
# 15                     Sales  956361           8
# 16  Research and Development  867544          12
# 17                Accounting  609929          19
# 19                Accounting  685974          14
# 20                  Services  826972          13
# 23                     Sales  996616          17
# 24                  Training  629115          17
# 25                     Sales  626195           8
# 26                Accounting  751945          16
# 29                  Training  817825          16
# 31                     Legal  830879          15
# 32                   Support  841927          20
# 33           Human Resources  877198           8
# 36                  Training  877554           8
# 38                  Services  577500          11
# 42                Accounting  815253           7
# 43                     Legal  942337           8
# 44      Business Development  805894          15
# 45        Product Management  746717          14
# 46                   Support  714347           6
# 48           Human Resources  574264          12
# 49                Accounting  723449           4
# 50           Human Resources  841007          18
# 53                 Marketing  708664           3
# 58  Research and Development  636457           1
# 63                   Support  746771           6
# 64      Business Development  947332           6
# 67        Product Management  792320          10
# 69                 Marketing  989818          11
# 70      Business Development  976939          18
# 71                  Services  611639          12
# 74        Product Management  630784          15
# 77                  Training  606185          20
# 80        Product Management  760705          18
# 81           Human Resources  830935          19
# 83                     Sales  730693          12
# 85                  Services  790440          12
# 86                   Support  962655          13
# 87                     Sales  840427           2
# 88                   Support  540659          13
# 89                     Sales  862563          16
# 90               Engineering  796605           1
# 91  Research and Development  596168          11
# 93               Engineering  835912           6

# %%
# Sort Employees Based on Salary in Descending Order
sorted_employees_by_salary = df.sort_values(by='salary', ascending=False)
print("Employees Sorted by Salary in Descending Order:")
print(sorted_employees_by_salary)
# Out:
# Employees Sorted by Salary in Descending Order:
#     emp_id                 name  age                         email  \
# 23      24        Emlynne Keary   21         ekearyn@over-blog.com
# 69      70          Booth Hehir   56    bhehir1x@ezinearticles.com
# 70      71      Carlene Cropper   45      ccropper1y@wordpress.com
# 86      87    Carolyne Castelin   45     ccastelin2e@goodreads.com
# 15      16       Cynthy Greenin   25     cgreeninf@statcounter.com
# ..     ...                  ...  ...                           ...
# 99     100         Randi Pucker   43           rpucker2r@diigo.com
# 98      99        Fonsie Parlor   33         fparlor2q@godaddy.com
# 84      85        Britte Becker   41             bbecker2c@ucoz.ru
# 5        6        Nonnah Fogden   47      nfogden5@bizjournals.com
# 34      35  Helaina Meadowcraft   18  hmeadowcrafty@cloudflare.com
#
#               department  salary  experience
# 23                 Sales  996616          17
# 69             Marketing  989818          11
# 70  Business Development  976939          18
# 86               Support  962655          13
# 15                 Sales  956361           8
# ..                   ...     ...         ...
# 99             Marketing   51941          12
# 98       Human Resources   49373           8
# 84              Services   39877          15
# 5   Business Development   28288          20
# 34  Business Development   12152          14
#
# [100 rows x 7 columns]
